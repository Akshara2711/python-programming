# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('anagrams')
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
sns.load_dataset('car_crashes').head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
a=sns.load_dataset('car_crashes')
import matplotlib.pyplot as plt
plt.scatter(a.speeding,a.alcohol)
plt.show()

# %%
a=sns.load_dataset('tips')
plt.scatter(a.tip,a.sex)
sns.set_style('ticks')
plt.show()

# %%
a=sns.load_dataset('car_crashes')
plt.scatter(a.speeding,a.alcohol)
sns.set_context('notebook')
plt.show()

# %%
plt.scatter(a.speeding,a.alcohol)
sns.palplot(sns.color_palette('bright'))

# %%
a=sns.load_dataset('tips')
sns.relplot(data=a,x='total_bill',y='tip')

# %%
a=sns.load_dataset('titanic')
sns.relplot(data=a,x='sex',y='age',hue='sex')

# %%
ir=sns.load_dataset('iris').head()
ir
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.displot(ir['sepal_width'])

# %%
sns.displot(ir['petal_width'])

# %%
sns.load_dataset('titanic').head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df=sns.load_dataset('titanic')

# %%
sns.barplot(data=df,x='embark_town',y='sex',orient='h')
sns.palplot(sns.color_palette('bright6'))

# %%
df=sns.load_dataset('titanic')

# %%
sns.countplot(data=df,x='class',hue='who',palette='magma')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
df=sns.load_dataset('tips')

# %%
sns.pointplot(data=df,x='day',y='tip',hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
df=sns.load_dataset('tips')

# %%
sns.jointplot(data=df,x='total_bill',y='tip',kind='hex')

# %%
df=sns.load_dataset('tips')

# %%
sns.regplot(data=df,x='total_bill',y='tip',x_jitter=10)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(data=df,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df=sns.violinplot(data=df,x='total_bill')

# %%
df=sns.load_dataset('tips')
sns.violinplot(data=df,x='day',y='total_bill',hue='smoker',split=2)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df=sns.load_dataset('tips')
sns.stripplot(data=df,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
[[10000, 12000, 13100, 14600, 15000, 15800, 16300, 17000, 17300, 18400, 19000, 20000]]
